# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
from datetime import datetime, timedelta
import time
import os
from pathlib import Path
from dotenv import load_dotenv

# %% [markdown]
# ## **Data Gathering & Preparation**

# %% [markdown]
# ### Get S&P 500 Data

# %%
# Import historical S&P 500 data (csv)
sp500_path = Path("resources/^GSPC.csv")  # Source: Yahoo Finance (https://finance.yahoo.com/quote/%5EGSPC/history?period1=-1325635200&period2=1597708800&interval=1d&filter=history&frequency=1d)
sp500_df = pd.read_csv(sp500_path)
sp500_df.tail()
# Out:
#              Date         Open         High          Low        Close  \
# 23262  2020-08-11  3370.340088  3381.010010  3326.439941  3333.689941
# 23263  2020-08-12  3355.459961  3387.889893  3355.459961  3380.350098
# 23264  2020-08-13  3372.949951  3387.239990  3363.350098  3373.429932
# 23265  2020-08-14  3368.659912  3378.510010  3361.639893  3372.850098
# 23266  2020-08-17  3380.860107  3387.590088  3379.219971  3381.989990
#
#          Adj Close      Volume
# 23262  3333.689941  5087650000
# 23263  3380.350098  3768560000
# 23264  3373.429932  3648810000
# 23265  3372.850098  3193400000
# 23266  3381.989990  3671290000

# %%
# Clean historical S&P 500
# sp500_df = sp500_df.set_index('Date')
sp500_daily_historical = sp500_df.drop(columns=['Open', 'High', 'Low', 'Close', 'Volume'])
sp500_daily_historical = sp500_daily_historical.rename(columns={'Adj Close':'S&P 500'})
sp500_daily_historical = sp500_daily_historical.round(2)
sp500_daily_historical = sp500_daily_historical[:-3]
sp500_daily_historical['Date'] = pd.to_datetime(sp500_daily_historical['Date'])
sp500_daily_historical = sp500_daily_historical.set_index('Date')
# sp500_daily_historical.tail(3)

# %%
# Get most recent S&P 500 data 
import pandas_datareader.data as web
import datetime

# last_historical_day = sp500_daily_historical.iloc[-1]['Date']
# start = datetime.datetime.strptime(last_historical_day, '%Y-%m-%d').date()
# end = datetime.date.today()
sp500_current = web.DataReader(['sp500'], 'fred')
sp500_current = sp500_current.reset_index()
sp500_current = sp500_current.rename(columns={'DATE':'Date', 'sp500':'S&P 500'})
sp500_current = sp500_current.set_index('Date')
sp500_current.info()
# print(start, end)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1303 entries, 2015-08-31 to 2020-08-26
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S&P 500  1257 non-null   float64
# dtypes: float64(1)
# memory usage: 20.4 KB

# %%
# Combine Historical S&P and Most recent S&P
sp500_daily = pd.concat([sp500_daily_historical, sp500_current], axis=0, join='outer')
# sp500_daily = pd.merge(sp500_daily_historical, sp500_current, left_on= ['Date', 'S&P 500'],
#                    right_on= ['DATE', 'sp500'], how='outer')
sp500_daily = sp500_daily.loc['1980':]
sp500_daily.plot(figsize=(20,10))

# %%
sp500_daily.head()
# Out:
#             S&P 500
# Date
# 1980-01-02   105.76
# 1980-01-03   105.22
# 1980-01-04   106.52
# 1980-01-07   106.81
# 1980-01-08   108.95

# %%
# Check if combined properly (Check if duplicate date)

# sp500_daily = sp500_daily.reset_index()
# sp500_daily[sp500_daily.duplicated(['Date'])]
# sp500_daily['Date'] = sp500_daily['Date'].drop_duplicates()
# sp500_daily = sp500_daily.set_index('Date')

# %%
# Drop rows with duplicated datetime index
sp500_daily['index'] = sp500_daily.index
sp500_daily= sp500_daily.drop_duplicates('index')
sp500_daily.set_index = sp500_daily['index']
sp500_daily= sp500_daily.drop('index', axis =1)

sp500_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10298 entries, 1980-01-02 to 2020-08-26
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S&P 500  10252 non-null  float64
# dtypes: float64(1)
# memory usage: 160.9 KB

# %%
# Check if csv exist. If not, create new saved_stock csv (with sp500 in it)
stock_data_path = Path("resources/saved_stock.csv")
try:
    df = pd.read_csv(stock_data_path)
    print('csv exist')

except FileNotFoundError:
    sp500_daily.to_csv("resources/saved_stock.csv")
    print('No csv. Created new one')
# Out:
# csv exist

# %%
# sp500_daily.head()
sp500_daily.plot()

# %%
# Calculate Daily Returns - S&P 500
sp500_returns = sp500_daily.pct_change()
sp500_returns = sp500_returns.dropna()
sp500_returns.plot(figsize=(20,10))

# %%
# Calculate Cumulative Returns - S&P 500
sp500_cum_returns = (1+sp500_returns).cumprod()
sp500_cum_returns.plot(figsize=(20,10))

# THE GRAPH SHOWS BARCODE LIKE PATTERN AFTER 2015.   FIX THIS!!!!!!!

# %%
# Calculate Standard Deviation - S&P 500
sp500_std = sp500_returns.std()
sp500_std
# Out:
# S&P 500    0.011286
# dtype: float64

# %% [markdown]
# ### Get Stock Data

# %%
load_dotenv()
# Out:
# True

# %%
# Get alpha-vantage api key
alphavantage_api_key = os.getenv("ALPHAVANTAGE_API_KEY")
type(alphavantage_api_key)
# Out:
# str

# %%
# import alpha-vantage
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.timeseries import TimeSeries

ts = TimeSeries(key=alphavantage_api_key, output_format='pandas')

# %%
# def get_daily(quote):
#     """GET stock's daily adjusted data using alpha vantage api """
#     data, meta_data = ts.get_daily_adjusted(quote, outputsize='full')
#     data = data.sort_index(ascending=True)
#     return data

# %%
# def setup_adjusted_close(quote, stock_data):
#     """Clean stock data: drop col, rename col"""
#     stock_data = stock_data.drop(columns=['1. open', '2. high', '3. low', '4. close',
#            '6. volume', '7. dividend amount', '8. split coefficient'])
#     stock_data = stock_data.rename(columns = {'5. adjusted close':quote})
#     stock_data.index.names = ['Date']
#     #     stock_data.dropna(inplace=True)
#     return stock_data

# %%
# Load saved stock data (from previous runs)
stock_data_path = Path('resources/saved_stock.csv')
saved_stock_df = pd.read_csv(stock_data_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
saved_stock_df.head(3)
# Out:
#             S&P 500  EA  TTWO  ATVI
# Date
# 1980-01-02   105.76 NaN   NaN   NaN
# 1980-01-03   105.22 NaN   NaN   NaN
# 1980-01-04   106.52 NaN   NaN   NaN

# %%
# Get stock data from Alpha Vantage (if not already in csv)
def get_daily(df, get_stock_list, saved_stock_quote_list):
    """If stock not in saved df, call api (timeout for api request limit. AlphaVantage - 5 requests/min)"""

    for stock in get_stock_list:
        if stock not in saved_stock_quote_list:
            print('call api for ' + stock)
            data, meta_data = ts.get_daily_adjusted(stock, outputsize='full')
            df[stock] = data['5. adjusted close'].sort_index(ascending=True)
            time.sleep(12)
    return df

    
stock_list = ['EA', 'TTWO', 'ATVI',  # stocks to get from Alpha Vantage
             'XON', 'CVX', 'COP', 'HAL', 'KMI', 'PSX', 'EPD', 'ET', 'PAA',
             'LMT', 'RTN', 'LDOS', 'BA', 'NOC', 'GD', 'OSK', 'KBR',
             'FB', 'AAPL', 'AMZN', 'NFLX', 'GOOG', 'MSFT', 'IBM', 'INTC', 'PYPL',
             'GS', 'JPM', 'MS', 'BAC', 'C', 'CS', 'UBS',
             'UAL', 'LUV', 'DAL', 'AAL', 'ALK', 'JBLU', 'SAVE',
             'WM', 'RSG', 'WCN']  
saved_stock_quotes = list(saved_stock_df.columns)  # stocks already saved in csv
all_portfolio = get_daily(saved_stock_df, stock_list, saved_stock_quotes) # Get stock from AlphaVantage api
all_portfolio = all_portfolio.sort_index(ascending=True)
all_portfolio.tail()
# Out:
# call api for JPM
# call api for MS
# call api for BAC
# call api for C
# call api for CS
# call api for UBS
# call api for UAL
# call api for LUV
# call api for DAL
# call api for AAL
# call api for ALK
# call api for JBLU
# call api for SAVE
# call api for WM
# call api for RSG
# call api for WCN
#             S&P 500      EA    TTWO    ATVI   XON    CVX    COP    HAL    KMI  \
# Date
# 2020-08-18  3389.78  142.58  176.98  83.130  4.89  87.63  40.33  16.45  14.38
# 2020-08-19  3374.85  141.86  172.63  81.980  5.28  86.39  39.65  16.49  14.12
# 2020-08-20  3385.51  143.48  174.43  83.995  5.57  84.81  38.77  16.01  14.06
# 2020-08-21  3397.16  141.21  173.14  83.210  6.09  85.08  38.16  15.74  14.11
# 2020-08-24  3431.28  142.33  172.55  83.100  5.55  87.20  38.87  16.29  14.24
#
#               PSX  ...    UAL    LUV    DAL    AAL    ALK   JBLU   SAVE  \
# Date               ...
# 2020-08-18  61.31  ...  33.98  34.16  27.63  12.60  36.19  11.05  17.32
# 2020-08-19  61.42  ...  34.44  34.27  27.67  12.68  35.85  10.98  17.19
# 2020-08-20  60.97  ...  34.05  34.46  27.62  12.50  35.77  10.82  17.21
# 2020-08-21  60.97  ...  33.04  34.69  27.27  12.16  35.43  10.56  16.98
# 2020-08-24  63.65  ...  36.32  36.91  29.80  13.44  37.52  11.43  18.21
#
#                 WM    RSG     WCN
# Date
# 2020-08-18  111.01  89.12   99.97
# 2020-08-19  110.56  89.15   99.58
# 2020-08-20  110.15  88.99   99.48
# 2020-08-21  111.16  89.81   99.38
# 2020-08-24  112.51  91.08  100.13
#
# [5 rows x 47 columns]

# %%
# def test_get_daily():
#     """ TEST get_daily. Should print 'call api for EA, stock exist', call api for ATVI"""
#     df = pd.DataFrame({'DATE':pd.date_range('2017-01-01', periods=5, freq='D'), 'FB':[1,2,3,4,5], 'AMZN':[7,6,9,8,0]})
#     df = df.set_index('DATE')
# #     test_stock_list = ['EA', 'FB', 'ATVI']
#     test_stock_list = ['EA', 'FB']
#     test_saved_stock_quotes = list(df.columns)
    
#     #Below - Code for get_daily()
#     for stock in test_stock_list:
#         if stock in test_saved_stock_quotes:
#             print('stock exist')
#         else:
#             data, meta_data = ts.get_daily_adjusted(stock, outputsize='full')
#             df[stock] = data['5. adjusted close'].sort_index(ascending=True)
#             print('call api for ' + stock)
#             time.sleep(12)
#     return df

# print(test_get_daily())

# %%
# Check data, ensure no duplicated datetime index 
all_portfolio.info()
idx = all_portfolio.index
print("\n" "number of duplicated datetime index: " + str(idx.duplicated().sum()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10296 entries, 1980-01-02 to 2020-08-24
# Data columns (total 47 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S&P 500  10250 non-null  float64
#  1   EA       5237 non-null   float64
#  2   TTWO     5237 non-null   float64
#  3   ATVI     5237 non-null   float64
#  4   XON      1774 non-null   float64
#  5   CVX      5237 non-null   float64
#  6   COP      5237 non-null   float64
#  7   HAL      5237 non-null   float64
#  8   KMI      2399 non-null   float64
#  9   PSX      2106 non-null   float64
#  10  EPD      5237 non-null   float64
#  11  ET       466 non-null    float64
#  12  PAA      5237 non-null   float64
#  13  LMT      5237 non-null   float64
#  14  RTN      5139 non-null   float64
#  15  LDOS     3489 non-null   float64
#  16  BA       5237 non-null   float64
#  17  NOC      5237 non-null   float64
#  18  GD       5237 non-null   float64
#  19  OSK      5237 non-null   float64
#  20  KBR      3465 non-null   float64
#  21  FB       2080 non-null   float64
#  22  AAPL     5237 non-null   float64
#  23  AMZN     5237 non-null   float64
#  24  NFLX     4596 non-null   float64
#  25  GOOG     1615 non-null   float64
#  26  MSFT     5237 non-null   float64
#  27  IBM      5237 non-null   float64
#  28  INTC     5237 non-null   float64
#  29  PYPL     1285 non-null   float64
#  30  GS       5237 non-null   float64
#  31  JPM      5237 non-null   float64
#  32  MS       5237 non-null   float64
#  33  BAC      5237 non-null   float64
#  34  C        5237 non-null   float64
#  35  CS       5237 non-null   float64
#  36  UBS      1448 non-null   float64
#  37  UAL      3663 non-null   float64
#  38  LUV      5237 non-null   float64
#  39  DAL      3352 non-null   float64
#  40  AAL      3753 non-null   float64
#  41  ALK      4936 non-null   float64
#  42  JBLU     4625 non-null   float64
#  43  SAVE     2327 non-null   float64
#  44  WM       5237 non-null   float64
#  45  RSG      5237 non-null   float64
#  46  WCN      5237 non-null   float64
# dtypes: float64(47)
# memory usage: 3.8 MB
#
# number of duplicated datetime index: 0

# %%
# Save stock into csv 
all_portfolio.to_csv("resources/saved_stock.csv")
all_portfolio.tail(3)
# Out:
#             S&P 500      EA    TTWO    ATVI   XON    CVX    COP    HAL    KMI  \
# Date
# 2020-08-20  3385.51  143.48  174.43  83.995  5.57  84.81  38.77  16.01  14.06
# 2020-08-21  3397.16  141.21  173.14  83.210  6.09  85.08  38.16  15.74  14.11
# 2020-08-24  3431.28  142.33  172.55  83.100  5.55  87.20  38.87  16.29  14.24
#
#               PSX  ...    UAL    LUV    DAL    AAL    ALK   JBLU   SAVE  \
# Date               ...
# 2020-08-20  60.97  ...  34.05  34.46  27.62  12.50  35.77  10.82  17.21
# 2020-08-21  60.97  ...  33.04  34.69  27.27  12.16  35.43  10.56  16.98
# 2020-08-24  63.65  ...  36.32  36.91  29.80  13.44  37.52  11.43  18.21
#
#                 WM    RSG     WCN
# Date
# 2020-08-20  110.15  88.99   99.48
# 2020-08-21  111.16  89.81   99.38
# 2020-08-24  112.51  91.08  100.13
#
# [3 rows x 47 columns]

# %% [markdown]
# ## **Portfolio Analysis**

# %% [markdown]
# ### Data Preparation

# %%
# Import csv
df = pd.read_csv("resources/saved_stock.csv", index_col="Date", parse_dates=True, infer_datetime_format=True)
len(df.columns)
# Out:
# 47

# %% [markdown]
# #### Set Time Frame (Years of record to analyze)

# %%
# Drop stock data with less than n years of record (due to lack of historical data in source, and bc it's been public for less than n years)
# Get stock data with more than n years of historical data

# Set time variables
n_years = 15  # Years of historical data to analyze from now
today = datetime.now()
start_year = (today - timedelta(days=n_years*365)).year  # the year n_years away from now

lt_n_yr_stocks = [col for col in df if df[col].count() < (252 * n_years)]  # 252 trading days in a year
all_portfolio = df.drop(columns=lt_n_yr_stocks)
all_portfolio = all_portfolio.loc[str(start_year):]

print(f'Stocks dropped (stocks with less than {n_years} years of historical data): \n {lt_n_yr_stocks}')
print()
all_portfolio.info()
# Out:
# Stocks dropped (stocks with less than 15 years of historical data):
#  ['XON', 'KMI', 'PSX', 'ET', 'LDOS', 'KBR', 'FB', 'GOOG', 'PYPL', 'UBS', 'UAL', 'DAL', 'AAL', 'SAVE']
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3984 entries, 2005-01-03 to 2020-08-24
# Data columns (total 33 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S&P 500  3938 non-null   float64
#  1   EA       3938 non-null   float64
#  2   TTWO     3938 non-null   float64
#  3   ATVI     3938 non-null   float64
#  4   CVX      3938 non-null   float64
#  5   COP      3938 non-null   float64
#  6   HAL      3938 non-null   float64
#  7   EPD      3938 non-null   float64
#  8   PAA      3938 non-null   float64
#  9   LMT      3938 non-null   float64
#  10  RTN      3840 non-null   float64
#  11  BA       3938 non-null   float64
#  12  NOC      3938 non-null   float64
#  13  GD       3938 non-null   float64
#  14  OSK      3938 non-null   float64
#  15  AAPL     3938 non-null   float64
#  16  AMZN     3938 non-null   float64
#  17  NFLX     3938 non-null   float64
#  18  MSFT     3938 non-null   float64
#  19  IBM      3938 non-null   float64
#  20  INTC     3938 non-null   float64
#  21  GS       3938 non-null   float64
#  22  JPM      3938 non-null   float64
#  23  MS       3938 non-null   float64
#  24  BAC      3938 non-null   float64
#  25  C        3938 non-null   float64
#  26  CS       3938 non-null   float64
#  27  LUV      3938 non-null   float64
#  28  ALK      3933 non-null   float64
#  29  JBLU     3938 non-null   float64
#  30  WM       3938 non-null   float64
#  31  RSG      3938 non-null   float64
#  32  WCN      3938 non-null   float64
# dtypes: float64(33)
# memory usage: 1.0 MB

# %% [markdown]
# #### Set Industry Portfolio

# %%
# Set Industry Portfolio
def set_portfolio(all_portfolio, industry_stocks_ls):
    """Get industry stock data from portfolio if it exist"""
    industry_portfolio = all_portfolio[[stock for stock in industry_stocks_ls if stock in all_portfolio]]
    return industry_portfolio

# Define stocks in each industry
gaming_industry = ['EA', 'TTWO', 'ATVI']
oil_industry = ['XON', 'CVX', 'COP', 'HAL', 'KMI', 'PSX', 'EPD', 'ET', 'PAA']
defense_industry = ['LMT', 'RTN', 'LDOS', 'BA', 'NOC', 'GD', 'OSK', 'KBR']
tech_industry = ['FB', 'AAPL', 'AMZN', 'NFLX', 'GOOG', 'MCST', 'IBM', 'INTC', 'PYPL']
finance_industry = ['GS' 'JPM', 'MS', 'BAC', 'C', 'CS', 'UBS']
airlines_industry = ['UAL', 'LUV', 'DAL', 'AAL', 'ALK', 'JBLU', 'SAVE']
wasteservice_industry = ['WM', 'RSG', 'WCN']

# Set industry portfolio (DataFrame)
sp500_index = set_portfolio(all_portfolio, ['S&P 500'])
gaming_portfolio = set_portfolio(all_portfolio, gaming_industry)
oil_portfolio = set_portfolio(all_portfolio, oil_industry)
defense_portfolio = set_portfolio(all_portfolio, defense_industry)
tech_portfolio = set_portfolio(all_portfolio, tech_industry)
finance_portfolio = set_portfolio(all_portfolio, finance_industry)
airlines_portfolio = set_portfolio(all_portfolio, airlines_industry)
wasteservices_portfolio = set_portfolio(all_portfolio, wasteservice_industry)

# Print remaining stocks in each portfolio (After filtering by length of history)
industry_portfolio_list = [sp500_index, gaming_portfolio, oil_portfolio , defense_portfolio, tech_portfolio , finance_portfolio , airlines_portfolio , wasteservices_portfolio] 
industry_names = ['sp500_index', 'gaming_portfolio', 'oil_portfolio' , 'defense_portfolio', 'tech_portfolio' , 'finance_portfolio' , 'airlines_portfolio' , 'wasteservices_portfolio'] 

for i in range(len(industry_portfolio_list)):
    print(f'{industry_names[i]} {list(industry_portfolio_list[i].columns)}')

# Check data
pd.concat(industry_portfolio_list, axis=1).tail()
# Out:
# sp500_index ['S&P 500']
# gaming_portfolio ['EA', 'TTWO', 'ATVI']
# oil_portfolio ['CVX', 'COP', 'HAL', 'EPD', 'PAA']
# defense_portfolio ['LMT', 'RTN', 'BA', 'NOC', 'GD', 'OSK']
# tech_portfolio ['AAPL', 'AMZN', 'NFLX', 'IBM', 'INTC']
# finance_portfolio ['MS', 'BAC', 'C', 'CS']
# airlines_portfolio ['LUV', 'ALK', 'JBLU']
# wasteservices_portfolio ['WM', 'RSG', 'WCN']
#             S&P 500      EA    TTWO    ATVI    CVX    COP    HAL    EPD   PAA  \
# Date
# 2020-08-18  3389.78  142.58  176.98  83.130  87.63  40.33  16.45  18.43  7.40
# 2020-08-19  3374.85  141.86  172.63  81.980  86.39  39.65  16.49  18.26  7.36
# 2020-08-20  3385.51  143.48  174.43  83.995  84.81  38.77  16.01  18.16  7.45
# 2020-08-21  3397.16  141.21  173.14  83.210  85.08  38.16  15.74  18.12  7.28
# 2020-08-24  3431.28  142.33  172.55  83.100  87.20  38.87  16.29  18.08  7.17
#
#                LMT  ...     MS    BAC      C     CS    LUV    ALK   JBLU  \
# Date                ...
# 2020-08-18  390.26  ...  50.92  25.53  50.34  11.11  34.16  36.19  11.05
# 2020-08-19  390.05  ...  51.37  25.50  50.29  11.15  34.27  35.85  10.98
# 2020-08-20  387.88  ...  50.80  25.10  49.58  11.04  34.46  35.77  10.82
# 2020-08-21  389.57  ...  51.10  24.98  49.30  10.96  34.69  35.43  10.56
# 2020-08-24  395.04  ...  52.37  25.69  51.06  11.15  36.91  37.52  11.43
#
#                 WM    RSG     WCN
# Date
# 2020-08-18  111.01  89.12   99.97
# 2020-08-19  110.56  89.15   99.58
# 2020-08-20  110.15  88.99   99.48
# 2020-08-21  111.16  89.81   99.38
# 2020-08-24  112.51  91.08  100.13
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Get Industry Returns

# %% [raw]
# sp500_index
# gaming_portfolio
# oil_portfolio
# defense_portfolio
# tech_portfolio
# finance_portfolio
# airlines_portfolio
# wasteservices_portfolio

# %%
# Get all stock returns in each portfolio
sp500_returns = sp500_index.pct_change()
gaming_returns = gaming_portfolio.pct_change()
oil_returns = oil_portfolio.pct_change()
defense_returns = defense_portfolio.pct_change()
tech_returns = tech_portfolio.pct_change()
finance_returns = finance_portfolio.pct_change()
airlines_returns = airlines_portfolio.pct_change()
wasteservices_returns = wasteservices_portfolio.pct_change()

# Get average returns in each portfolio
industry_portfolio_returns = pd.DataFrame(sp500_returns)
industry_portfolio_returns['GAMING'] = gaming_returns.mean(axis=1)
industry_portfolio_returns['OIL'] = oil_returns.mean(axis=1)
industry_portfolio_returns['DEFENSE'] = defense_returns.mean(axis=1)
industry_portfolio_returns['TECH'] = tech_returns.mean(axis=1)
industry_portfolio_returns['FINANCE'] = finance_returns.mean(axis=1)
industry_portfolio_returns['AIRLINES'] = airlines_returns.mean(axis=1)
industry_portfolio_returns['WASTESERVICES'] = wasteservices_returns.mean(axis=1)

industry_portfolio_returns = industry_portfolio_returns.dropna()
industry_portfolio_returns.head()
# Out:
#              S&P 500    GAMING       OIL   DEFENSE      TECH   FINANCE  \
# Date
# 2005-01-04 -0.011671 -0.032126 -0.003740 -0.026281 -0.019139 -0.011847
# 2005-01-05 -0.003628  0.005145 -0.002985  0.008907 -0.010256 -0.001503
# 2005-01-06  0.003506 -0.018844  0.016942 -0.002745 -0.005963  0.005975
# 2005-01-07 -0.001431 -0.014710 -0.003675 -0.000706  0.024173 -0.008497
# 2005-01-10  0.003423  0.011224  0.004027  0.006875  0.000081  0.001921
#
#             AIRLINES  WASTESERVICES
# Date
# 2005-01-04 -0.044343      -0.007992
# 2005-01-05 -0.014190      -0.009746
# 2005-01-06 -0.014527      -0.002134
# 2005-01-07 -0.000903      -0.010113
# 2005-01-10  0.001122       0.003889

# %% [markdown]
# ### Industry Analysis: Portfolio-to-Portfolio

# %% [markdown]
# #### Industry - Cumulative Returns

# %%
# Cumulative Returns - Industry
industry_portfolio_cumulative_returns = (1+industry_portfolio_returns).cumprod()
industry_portfolio_cumulative_returns.plot(figsize=(20,10), title="Industry - Daily Returns")
print('Cumulative Returns: By last day')
industry_portfolio_cumulative_returns.iloc[-1].sort_values(ascending=False)
# Out:
# Cumulative Returns: By last day
# TECH             48.689530
# GAMING           10.323041
# WASTESERVICES     8.937747
# DEFENSE           7.724954
# AIRLINES          3.024703
# S&P 500           2.854452
# OIL               2.592367
# FINANCE           0.813113
# Name: 2020-08-24 00:00:00, dtype: float64

# %% [markdown]
# ### Risk Analysis

# %% [markdown]
# #### Industry - Summary Statistics

# %%
# Summary Statistics
industry_portfolio_returns.describe()
# Out:
#            S&P 500       GAMING          OIL      DEFENSE         TECH  \
# count  3983.000000  3983.000000  3983.000000  3983.000000  3983.000000
# mean      0.000341     0.000780     0.000408     0.000616     0.001100
# std       0.012412     0.019695     0.018241     0.014308     0.015775
# min      -0.119841    -0.123932    -0.261961    -0.132627    -0.111261
# 25%      -0.003813    -0.009464    -0.006980    -0.005639    -0.006326
# 50%       0.000633     0.000279     0.000585     0.000959     0.001110
# 75%       0.005408     0.010661     0.008360     0.007299     0.009167
# max       0.115800     0.167770     0.216819     0.121540     0.114087
#
#            FINANCE     AIRLINES  WASTESERVICES
# count  3983.000000  3983.000000    3983.000000
# mean      0.000305     0.000560       0.000624
# std       0.026861     0.023797       0.012147
# min      -0.208474    -0.178920      -0.114754
# 25%      -0.008574    -0.010865      -0.004665
# 50%       0.000345     0.000046       0.000752
# 75%       0.009132     0.011633       0.006348
# max       0.330161     0.229952       0.113987

# %%
# Box Plot - Daily Returns - Gaming Portfolio
industry_portfolio_returns.plot.box(figsize=(20, 10), title="Industry Portfolio Risk")

# %% [markdown]
# #### Industry - Standard Deviation

# %%
# Daily Standard Deviation
industry_daily_std = industry_portfolio_returns.std()
industry_daily_std.sort_values(ascending=False)
# Out:
# FINANCE          0.026861
# AIRLINES         0.023797
# GAMING           0.019695
# OIL              0.018241
# TECH             0.015775
# DEFENSE          0.014308
# S&P 500          0.012412
# WASTESERVICES    0.012147
# dtype: float64

# %%
# Annual Standard Deviation
industry_annualized_std = industry_daily_std * np.sqrt(252)
industry_annualized_std.sort_values(ascending=False)
# Out:
# FINANCE          0.426402
# AIRLINES         0.377759
# GAMING           0.312653
# OIL              0.289572
# TECH             0.250419
# DEFENSE          0.227130
# S&P 500          0.197027
# WASTESERVICES    0.192835
# dtype: float64

# %% [markdown]
# #### Industry - Sharpe Ratio

# %% [markdown]
# Sharpe Ratio: Measures Return per Risk

# %%
daily_sharpe_ratio = industry_portfolio_returns.mean() / industry_daily_std
print('Daily Sharpe Ratio:')
daily_sharpe_ratio.sort_values(ascending=False)
# Out:
# Daily Sharpe Ratio:
# TECH             0.069759
# WASTESERVICES    0.051360
# DEFENSE          0.043061
# GAMING           0.039605
# S&P 500          0.027444
# AIRLINES         0.023538
# OIL              0.022354
# FINANCE          0.011354
# dtype: float64

# %%
annualized_sharpe_ratio = (industry_portfolio_returns.mean() * 252) / industry_annualized_std
print('Annual Sharpe Ratio:')
annualized_sharpe_ratio.sort_values(ascending=False)
# Out:
# Annual Sharpe Ratio:
# TECH             1.107391
# WASTESERVICES    0.815320
# DEFENSE          0.683566
# GAMING           0.628717
# S&P 500          0.435653
# AIRLINES         0.373650
# OIL              0.354862
# FINANCE          0.180234
# dtype: float64

# %% [markdown]
# #### Industry - Beta

# %% [markdown]
# Beta: Measures Risk relative to the Market (S&P 500)

# %%
# Covariance of each portfolio relative to S&P 500
covariance_ls = [industry_portfolio_returns[stock].cov(industry_portfolio_returns['S&P 500']) for stock in industry_portfolio_returns.columns]
covariance = pd.Series(covariance_ls, index=industry_portfolio_returns.columns)
    
# Variance
variance = industry_portfolio_returns['S&P 500'].var()

# Beta
beta = covariance / variance

# Print Industry Portfolio Beta
print('Beta:')
beta.sort_values(ascending=False)
# Out:
# Beta:
# FINANCE          1.756519
# AIRLINES         1.167479
# OIL              1.075767
# S&P 500          1.000000
# TECH             0.991354
# GAMING           0.974048
# DEFENSE          0.940117
# WASTESERVICES    0.735037
# dtype: float64

# %% [markdown]
# #### Industry - Correlation

# %% [markdown]
# Correlation: Linear relationship between each portfolio (Range: 0~1)
#
# Usage: Portfolio Diversification
#
# - Can diversify portfolio by having stocks with least correlation with each other in the portfolio to spread risk (i.e. stocks with lower corr() score). You don't want to put all eggs in one basket.

# %%
# Correlation Heatmap
plt.title("Industry Portfolio Correlation")
# plt.figure(figsize=(20,20))
sns.heatmap(industry_portfolio_returns.corr())   # Visualize to find least correlated stocks

# %%
# Show which industries are least correlated with each other
industry_portfolio_returns.corr().sum().sort_values()
# Out:
# GAMING           4.300372
# AIRLINES         4.422963
# OIL              4.768628
# WASTESERVICES    4.983926
# TECH             5.051577
# FINANCE          5.200410
# DEFENSE          5.371260
# S&P 500          6.112853
# dtype: float64

# %% [markdown]
# ## Conclusion - Industry Analysis
#
# #### Invest in: Waste Services
#
# - Incredible return relative to risk. 2nd highest sharpe ratio after the tech industry portfolio
# - Very low risk: Lowest Beta and Standard Deviation (The only industry portfolio with standard deviation less than S&P 500 index)
# - 3rd highest cumulative returns over the past 15 years
#
# #### Avoid: Finance
#
# - Terrible return relative to risk. Lowest sharpe ratio (2nd lowest sharpe ratio, that of oil industry portfolio, is almost double that of finance industry portfolio)
# - Very high risk: Highest Beta and Standard Deviation
# - Very low return: The only industry portfolio with negative return over the past 15 years
#
# #### Portfolio Diversification
#
# - Invest in: Waste Services, Gaming, Tech
# - Waste services is least correlated with Gaming, Oil, and Tech.
# - Oil is not chosen because of its low return and high risk
#
# #### Limitations of the Analysis:
#
# - Lack of historical data from Alpha Vantage (free account). Had to drop a few stocks because not enough data.
# - Small number of stocks in each portfolio. Some portfolio were only comprised of 3 stocks
# - Industry category may not be entirely definite for some stocks. For example, TECH is comprised of IT companies, hardware companies, and even chip makers. OIL is comprised of up both upstream and downstream companies. Performance of upstream and downstream stocks may differ.
#
# #### Future Steps:
#
# - Find source with longer historical stock data
# - Perform this analysis again with more historical data and more stocks in each portfolio
# - Stock-to-Stock analysis within each portfolio
